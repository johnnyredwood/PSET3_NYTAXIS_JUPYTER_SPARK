# %%
# !pip install python-dotenv
# !pip install snowflake-connector-python
# Out:
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: snowflake-connector-python in /opt/conda/lib/python3.11/site-packages (4.0.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (41.0.4)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (23.2.0)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.8.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.31.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (23.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2023.7.22)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (4.8.0)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.20.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.11.0)
# Requirement already satisfied: tomlkit in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (0.13.3)
# Requirement already satisfied: boto3>=1.24 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.40.54)
# Requirement already satisfied: botocore>=1.24 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.40.54)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore>=1.24->snowflake-connector-python) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore>=1.24->snowflake-connector-python) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=3.1.0->snowflake-connector-python) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.1.0->snowflake-connector-python) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.24->snowflake-connector-python) (1.16.0)

# %%
from dotenv import load_dotenv
import os
import pyspark
from pyspark.sql import SparkSession
import requests
import json
from pyspark.sql import functions as F
from pyspark.sql.types import StringType
import time

# %%
# Cargo mis variables de entorno
load_dotenv()

# Genero el dict de datos para conectarme con Snowflake
credencialesSnowflakeRaw = {
    "sfURL" : os.getenv("SNOWFLAKE_URL"),
    "sfUser" :  os.getenv("SNOWFLAKE_USER"),
    "sfPassword" : os.getenv("SNOWFLAKE_PASSWORD"),
    "sfDatabase" : os.getenv("SNOWFLAKE_DATABASE"),
    "sfSchema" : os.getenv("SNOWFLAKE_SCHEMA_RAW"),
    "sfWarehouse" : os.getenv("SNOWFLAKE_WAREHOUSE"),
    "sfRole" : os.getenv("SNOWFLAKE_ROLE"),
}

print(f"Estas son mis credenciales para Snowflake: {credencialesSnowflakeRaw}")

# Creo SparkSession para conexión con Snowflake
spark = (SparkSession.builder.appName("IngestaNewYorkTaxis").config("spark.jars.packages", "net.snowflake:snowflake-jdbc:3.13.30,net.snowflake:spark-snowflake_2.12:2.9.0-spark_3.1").getOrCreate())

print(spark)
print("Spark Version : " + spark.version)

# Ejecuto una query de prueba para validar comunicacion con Snowflake
query = "SELECT current_version()"

df = spark.read.format("snowflake").options(**credencialesSnowflakeRaw).option("query", query).load()

df.show()
# Out:
# Estas son mis credenciales para Snowflake: {'sfURL': 'LSNDJXB-RHC82043.snowflakecomputing.com', 'sfUser': 'usuario_spark', 'sfPassword': 'EstudianteEstudiante64', 'sfDatabase': 'NY_TAXI', 'sfSchema': 'RAW', 'sfWarehouse': 'WAREHOUSE_TAXIS', 'sfRole': 'rol_pocos_privilegios'}
# <pyspark.sql.session.SparkSession object at 0x7f1d1c531150>
# Spark Version : 3.5.0
# +-------------------+
# |"CURRENT_VERSION()"|
# +-------------------+
# |             9.32.1|
# +-------------------+

# %%
def ingestar_zones_a_raw():
    SOURCE_PATH = os.getenv("SOURCE_PATH")
    path_url = f"{SOURCE_PATH}/misc/taxi_zone_lookup.csv"
    local_path = f"/tmp/taxiZones.parquet"
    
    # Descargo el archivo en carpeta temporal para posteriormente leerlo
    try:
        r = requests.get(path_url, stream=True)
        if r.status_code == 200:
            with open(local_path, 'wb') as f:
                for chunk in r.iter_content(chunk_size=10000000):
                    f.write(chunk)
        else:
            print(f"Archivo no encontrado en {path_url} (status {r.status_code})")
            return None
    except Exception as e:
        print(f"Error descargando {path_url}: {e}")
        return None
    else:
        print(f"Archivo obtenido exitosamente de: {path_url}")
    
    # Leo el archivo en un df de Spark
    try:
        df = spark.read.csv(local_path, header="true")
    except Exception as e:
        print(f"No se pudo leer {local_path}: {e}")
        return None
    else:
        print(f"Archivo leido exitosamente por Spark: {local_path}")

    conteoFilas = df.count()
    print(f"Ingestando hacia Snowflake datos de Zonas de Taxis. Total de filas: {conteoFilas}")

    try:
        df.write.format("snowflake") \
            .options(**credencialesSnowflakeRaw) \
            .option("dbtable", f"NY_TAXI_RAW_TAXI_ZONES") \
            .mode("overwrite") \
            .save()
    except Exception as e2:
        print(f"Error con tabla temporal: {e2}")
        return None
    else:
        print("Zonas de taxis exportadas correctamente a Raw de Snowflake")

    #Me aseguro de eliminar el archivo parquet temporal
    try:
        os.remove(local_path)
        print(f"Archivo parquet temporal removido: {local_path}")
    except OSError as e:
        print(f"No se pudo remover el archivo parquet temporal {local_path}: {e}")

    #Retorno datos para tabla de conteos de datos consumidos por run
    return {
        "count": conteoFilas,
    }

# %%
#Cargo Zonas de Taxis en Snowflake
zonasTaxisIngesta=ingestar_zones_a_raw()
print(zonasTaxisIngesta)
# Out:
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Archivo leido exitosamente por Spark: /tmp/taxiZones.parquet
# Ingestando hacia Snowflake datos de Zonas de Taxis. Total de filas: 265
# Zonas de taxis exportadas correctamente a Raw de Snowflake
# Archivo parquet temporal removido: /tmp/taxiZones.parquet
# {'count': 265}

# %%
#Defino funciones tipicas de checkpoint para en caso de fallo no ingestar datos desde cero

def save_checkpoint(year, month, CHECKPOINT_FILE_COMBINADO):
    with open(CHECKPOINT_FILE_COMBINADO, "w") as f:
        json.dump({"year": year, "month": month}, f)

def load_checkpoint(CHECKPOINT_FILE_COMBINADO):
    if os.path.exists(CHECKPOINT_FILE_COMBINADO):
        with open(CHECKPOINT_FILE_COMBINADO, "r") as f:
            return json.load(f)
    return {"year": 0, "month": 0}

# %%
# Función para aplicar normalización
def normalizar_catalogos(df):

    df_normalizado = df

    # Defino mapeos para normalización. Los defino como base en los data dictionary que hay en la pagina de los datos
    mapeo_payment_type = {
        0: 'Flex Fare trip',
        1: 'Credit card',
        2: 'Cash',
        3: 'No charge',
        4: 'Dispute',
        5: 'Unknown',
        6: 'Voided trip'
    }
    
    mapeo_rate_code = {
        1: 'Standard rate',
        2: 'JFK',
        3: 'Newark',
        4: 'Nassau or Westchester',
        5: 'Negotiated fare',
        6: 'Group ride',
        99: 'Unknown'
    }
    
    mapeo_vendor = {
        1: 'Creative Mobile Technologies,  LLC',
        2: 'Curb Mobility, LLC',
        6: 'Myle Technologies Inc',
        7: 'Helix'
    }
        
    # Normalizo payment_type
    if 'PAYMENT_TYPE' in df.columns:
        df_normalizado = df_normalizado.withColumn('PAYMENT_TYPE_NORMALIZADO',F.coalesce(
        F.create_map([F.lit(x) for item in mapeo_payment_type.items() for x in item])[F.col('PAYMENT_TYPE').cast('int')],
        F.lit('Unknown')))
        
    # Normalizo RateCode
    if 'RATECODEID' in df.columns:
        df_normalizado = df_normalizado.withColumn('RATE_CODE_NORMALIZADO',F.coalesce(
        F.create_map([F.lit(x) for item in mapeo_rate_code.items() for x in item])[F.col('RATECODEID').cast('int')],
        F.lit('Unknown')))
      
    # Normalizo VendorID
    if 'VENDORID' in df.columns:
        df_normalizado = df_normalizado.withColumn('VENDOR_NORMALIZADO',F.coalesce(
        F.create_map([F.lit(x) for item in mapeo_vendor.items() for x in item])[F.col('VENDORID').cast('int')],
        F.lit('Unknown')))
        
    return df_normalizado

# %%
def guardar_con_reintentos(df, tabla, reintentos=3):
    
    for intento in range(reintentos):
        try:
            print(f"Intento {intento + 1} de {reintentos} para guardar en {tabla}")
            df.write.format("snowflake") \
                .options(**credencialesSnowflakeRaw) \
                .option("dbtable", tabla) \
                .mode("append") \
                .save()
            print(f"Tabla {tabla} actualizada exitosamente")
            return True
        except Exception as e:
            print(f"Error en intento {intento + 1}: {str(e)[:200]}...")
            if intento < reintentos - 1:
                wait_time = 30 
                print(f"Esperando {wait_time} segundos antes del reintento")
                time.sleep(wait_time)
            else:
                print(f"Todos los intentos fallaron para {tabla}")
                raise e
    return False

def guardar_por_lotes(df, tabla, batch_size=100000):
    
    total_count = df.count()
    num_partitions = max(1, total_count // batch_size)
    
    print(f"Dividiendo {total_count} filas en {num_partitions} particiones")
    
    df_reparticionado = df.repartition(num_partitions)
    
    return guardar_con_reintentos(df_reparticionado, tabla)

# %%
def normalizar_y_unificar_taxis():

    #Unifico tablas yellow y green, normalizando catálogos de payment_type, rate_code y vendor
    print("Iniciando proceso de la unificacion y el enriquecimiento de datos de viajes de taxis en NY")
    # Leo las tablas desde Snowflake
    try:
        df_yellow = spark.read.format("snowflake") \
            .options(**credencialesSnowflakeRaw) \
            .option("dbtable", "NY_TAXI_RAW_YELLOW") \
            .load()
        
        df_green = spark.read.format("snowflake") \
            .options(**credencialesSnowflakeRaw) \
            .option("dbtable", "NY_TAXI_RAW_GREEN") \
            .load()
            
        print("Tablas yellow y green leídas exitosamente desde Snowflake")
        
    except Exception as e:
        print(f"Error leyendo tablas desde Snowflake: {e}")
        return None

    # Normalizo ambas tablas
    try:
        print("Normalizando tabla yellow")
        df_yellow_normalizado = normalizar_catalogos(df_yellow)
        
        print("Normalizando tabla green")
        df_green_normalizado = normalizar_catalogos(df_green)
        
        print("Catálogos normalizados exitosamente")
        
    except Exception as e:
        print(f"Error en normalización de catálogos: {e}")
        return None

    # Unifico las tablas
    try:
        
        columnas_yellow = set(df_yellow_normalizado.columns)
        columnas_green = set(df_green_normalizado.columns)
        CHECKPOINT_FILE_COMBINADO="checkpointCargaUnificado.json"
        
        if ( columnas_yellow == columnas_green):
            df_unificado = df_yellow_normalizado.select(*sorted(columnas_yellow)).unionByName(df_green_normalizado.select(*sorted(columnas_yellow)))
            conteo_filas = df_unificado.count()
            print(f"Tablas unificadas exitosamente. Total de filas: {conteo_filas}")

            lista_years = sorted([int(item) for item in (os.getenv("YEARS").split(','))])
            lista_months = sorted([int(item) for item in (os.getenv("MONTHS").split(','))])
            
            checkpoint=load_checkpoint(CHECKPOINT_FILE_COMBINADO)
            
            print(f"checkpoint: {checkpoint}")

            if ( checkpoint != {"year": 0, "month": 0} and (int(checkpoint["month"]) in lista_months) and (int(checkpoint["year"]) in lista_years)):    
                if ( int(checkpoint["month"]) == lista_months[-1] and int(checkpoint["year"]) != lista_years[-1] ):
                    lista_years= lista_years[lista_years.index(checkpoint["year"])+1:]
                elif ( int(checkpoint["month"]) != lista_months[-1] and int(checkpoint["year"]) != lista_years[-1] ): 
                    lista_years= lista_years[lista_years.index(checkpoint["year"]):]
                    lista_months= lista_months[lista_months.index(checkpoint["month"])+1:]
    
            for year in lista_years:
                for month in lista_months:
                    df_lote = df_unificado.filter((F.col("SOURCE_YEAR") == int(year)) & (F.col("SOURCE_MONTH") == int(month)))
                    print(f"Se han filtrado datos de year {year} + month {month}. Se procedera a cargarlos en la base de Snowflake")
                    guardar_por_lotes(df_lote, "NY_TAXI_TRIPS_UNIFIED", batch_size=100000)
                    print(f"Guardados correctamente datos de taxis de year {year} + month {month}")
                    save_checkpoint(year, month, CHECKPOINT_FILE_COMBINADO) 
                lista_months = sorted([int(item) for item in (os.getenv("MONTHS").split(','))])
                
        else:
            print(f"No se pudo unificar tablas")
            return None
        
    except Exception as e:
        print(f"Error unificando tablas: {e}")
        return None
    
    # Retorno estadísticas
    return {"total_filas": conteo_filas,"filas_yellow": df_yellow_normalizado.count(),"filas_green": df_green_normalizado.count()}

# %%
resultado = normalizar_y_unificar_taxis()
# Out:
# Iniciando proceso de la unificacion y el enriquecimiento de datos de viajes de taxis en NY
# Tablas yellow y green leídas exitosamente desde Snowflake
# Normalizando tabla yellow
# Normalizando tabla green
# Catálogos normalizados exitosamente
# Tablas unificadas exitosamente. Total de filas: 852432668
# checkpoint: {'year': 0, 'month': 0}
# Se han filtrado datos de year 2015 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14249528 filas en 142 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 1
# Se han filtrado datos de year 2015 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14017224 filas en 140 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 2
# Se han filtrado datos de year 2015 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 15065525 filas en 150 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 3
# Se han filtrado datos de year 2015 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14728152 filas en 147 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 4
# Se han filtrado datos de year 2015 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14944525 filas en 149 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 5
# Se han filtrado datos de year 2015 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13963804 filas en 139 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 6
# Se han filtrado datos de year 2015 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13101337 filas en 131 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 7
# Se han filtrado datos de year 2015 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12655466 filas en 126 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 8
# Se han filtrado datos de year 2015 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12713049 filas en 127 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 9
# Se han filtrado datos de year 2015 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13937869 filas en 139 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 10
# Se han filtrado datos de year 2015 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12835224 filas en 128 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 11
# Se han filtrado datos de year 2015 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13061293 filas en 130 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2015 + month 12
# Se han filtrado datos de year 2016 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12350359 filas en 123 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 1
# Se han filtrado datos de year 2016 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12886134 filas en 128 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 2
# Se han filtrado datos de year 2016 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13780217 filas en 137 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 3
# Se han filtrado datos de year 2016 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13471922 filas en 134 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 4
# Se han filtrado datos de year 2016 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13369028 filas en 133 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 5
# Se han filtrado datos de year 2016 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12536372 filas en 125 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 6
# Se han filtrado datos de year 2016 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11626590 filas en 116 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 7
# Se han filtrado datos de year 2016 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11189938 filas en 111 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 8
# Se han filtrado datos de year 2016 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11278391 filas en 112 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 9
# Se han filtrado datos de year 2016 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12107198 filas en 121 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 10
# Se han filtrado datos de year 2016 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11250342 filas en 112 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 11
# Se han filtrado datos de year 2016 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11670855 filas en 116 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2016 + month 12
# Se han filtrado datos de year 2017 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10780385 filas en 107 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 1
# Se han filtrado datos de year 2017 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10192088 filas en 101 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 2
# Se han filtrado datos de year 2017 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11453268 filas en 114 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 3
# Se han filtrado datos de year 2017 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11127979 filas en 111 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 4
# Se han filtrado datos de year 2017 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11161590 filas en 111 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 5
# Se han filtrado datos de year 2017 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10633460 filas en 106 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 6
# Se han filtrado datos de year 2017 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9503269 filas en 95 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 7
# Se han filtrado datos de year 2017 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9289560 filas en 92 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 8
# Se han filtrado datos de year 2017 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9827885 filas en 98 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 9
# Se han filtrado datos de year 2017 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10694409 filas en 106 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 10
# Se han filtrado datos de year 2017 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10158976 filas en 101 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 11
# Se han filtrado datos de year 2017 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10414517 filas en 104 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2017 + month 12
# Se han filtrado datos de year 2018 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9553431 filas en 95 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 1
# Se han filtrado datos de year 2018 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9262016 filas en 92 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 2
# Se han filtrado datos de year 2018 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10267535 filas en 102 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 3
# Se han filtrado datos de year 2018 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10105599 filas en 101 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 4
# Se han filtrado datos de year 2018 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10021340 filas en 100 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 5
# Se han filtrado datos de year 2018 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9453213 filas en 94 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 6
# Se han filtrado datos de year 2018 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8535517 filas en 85 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 7
# Se han filtrado datos de year 2018 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8530855 filas en 85 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 8
# Se han filtrado datos de year 2018 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8731126 filas en 87 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 9
# Se han filtrado datos de year 2018 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9566408 filas en 95 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 10
# Se han filtrado datos de year 2018 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8828736 filas en 88 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 11
# Se han filtrado datos de year 2018 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8915329 filas en 89 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2018 + month 12
# Se han filtrado datos de year 2019 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8368722 filas en 83 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 1
# Se han filtrado datos de year 2019 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7664964 filas en 76 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 2
# Se han filtrado datos de year 2019 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8509683 filas en 85 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 3
# Se han filtrado datos de year 2019 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8043801 filas en 80 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 4
# Se han filtrado datos de year 2019 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8143897 filas en 81 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 5
# Se han filtrado datos de year 2019 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7477798 filas en 74 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 6
# Se han filtrado datos de year 2019 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6781162 filas en 67 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 7
# Se han filtrado datos de year 2019 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6523052 filas en 65 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 8
# Se han filtrado datos de year 2019 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7016851 filas en 70 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 9
# Se han filtrado datos de year 2019 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7690277 filas en 76 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 10
# Se han filtrado datos de year 2019 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7327611 filas en 73 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 11
# Se han filtrado datos de year 2019 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7351611 filas en 73 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2019 + month 12
# Se han filtrado datos de year 2020 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6852778 filas en 68 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 1
# Se han filtrado datos de year 2020 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6697999 filas en 66 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 2
# Se han filtrado datos de year 2020 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3231183 filas en 32 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 3
# Se han filtrado datos de year 2020 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 273717 filas en 2 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 4
# Se han filtrado datos de year 2020 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 405776 filas en 4 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 5
# Se han filtrado datos de year 2020 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 612907 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 6
# Se han filtrado datos de year 2020 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 872670 filas en 8 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 7
# Se han filtrado datos de year 2020 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1088349 filas en 10 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 8
# Se han filtrado datos de year 2020 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1429004 filas en 14 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 9
# Se han filtrado datos de year 2020 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1776252 filas en 17 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 10
# Se han filtrado datos de year 2020 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1597605 filas en 15 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 11
# Se han filtrado datos de year 2020 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1545028 filas en 15 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2020 + month 12
# Se han filtrado datos de year 2021 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1446287 filas en 14 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 1
# Se han filtrado datos de year 2021 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1436281 filas en 14 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 2
# Se han filtrado datos de year 2021 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2008979 filas en 20 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 3
# Se han filtrado datos de year 2021 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2258128 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 4
# Se han filtrado datos de year 2021 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2595289 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 5
# Se han filtrado datos de year 2021 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2921001 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 6
# Se han filtrado datos de year 2021 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2905437 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 7
# Se han filtrado datos de year 2021 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2872256 filas en 28 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 8
# Se han filtrado datos de year 2021 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3059502 filas en 30 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 9
# Se han filtrado datos de year 2021 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3574395 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 10
# Se han filtrado datos de year 2021 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3581178 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 11
# Se han filtrado datos de year 2021 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3314330 filas en 33 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2021 + month 12
# Se han filtrado datos de year 2022 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2526426 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 1
# Se han filtrado datos de year 2022 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3048830 filas en 30 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 2
# Se han filtrado datos de year 2022 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3706419 filas en 37 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 3
# Se han filtrado datos de year 2022 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3676056 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 4
# Se han filtrado datos de year 2022 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3665186 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 5
# Se han filtrado datos de year 2022 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3631842 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 6
# Se han filtrado datos de year 2022 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3238586 filas en 32 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 7
# Se han filtrado datos de year 2022 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3218606 filas en 32 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 8
# Se han filtrado datos de year 2022 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3252798 filas en 32 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 9
# Se han filtrado datos de year 2022 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3744733 filas en 37 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 10
# Se han filtrado datos de year 2022 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3315030 filas en 33 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 11
# Se han filtrado datos de year 2022 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3471988 filas en 34 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2022 + month 12
# Se han filtrado datos de year 2023 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3134977 filas en 31 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 1
# Se han filtrado datos de year 2023 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2978764 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 2
# Se han filtrado datos de year 2023 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3475810 filas en 34 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 3
# Se han filtrado datos de year 2023 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3353642 filas en 33 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 4
# Se han filtrado datos de year 2023 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3582823 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 5
# Se han filtrado datos de year 2023 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3372783 filas en 33 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 6
# Se han filtrado datos de year 2023 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2968451 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 7
# Se han filtrado datos de year 2023 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2884858 filas en 28 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 8
# Se han filtrado datos de year 2023 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2912192 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 9
# Se han filtrado datos de year 2023 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3588462 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 10
# Se han filtrado datos de year 2023 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3403740 filas en 34 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 11
# Se han filtrado datos de year 2023 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3440782 filas en 34 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2023 + month 12
# Se han filtrado datos de year 2024 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3021174 filas en 30 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 1
# Se han filtrado datos de year 2024 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3061103 filas en 30 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 2
# Se han filtrado datos de year 2024 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3640085 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 3
# Se han filtrado datos de year 2024 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3570760 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 4
# Se han filtrado datos de year 2024 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3784836 filas en 37 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 5
# Se han filtrado datos de year 2024 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3593941 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 6
# Se han filtrado datos de year 2024 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3128740 filas en 31 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 7
# Se han filtrado datos de year 2024 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3030954 filas en 30 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 8
# Se han filtrado datos de year 2024 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3687470 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 9
# Se han filtrado datos de year 2024 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3889918 filas en 38 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 10
# Se han filtrado datos de year 2024 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3698591 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 11
# Se han filtrado datos de year 2024 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3722365 filas en 37 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2024 + month 12
# Se han filtrado datos de year 2025 + month 1. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3523552 filas en 35 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 1
# Se han filtrado datos de year 2025 + month 2. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3624164 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 2
# Se han filtrado datos de year 2025 + month 3. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 4196796 filas en 41 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 3
# Se han filtrado datos de year 2025 + month 4. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 4022685 filas en 40 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 4
# Se han filtrado datos de year 2025 + month 5. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 4647243 filas en 46 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 5
# Se han filtrado datos de year 2025 + month 6. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 4372350 filas en 43 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 6
# Se han filtrado datos de year 2025 + month 7. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3947167 filas en 39 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 7
# Se han filtrado datos de year 2025 + month 8. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3620397 filas en 36 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 8
# Se han filtrado datos de year 2025 + month 9. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 9
# Se han filtrado datos de year 2025 + month 10. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 10
# Se han filtrado datos de year 2025 + month 11. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 11
# Se han filtrado datos de year 2025 + month 12. Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_TRIPS_UNIFIED
# Tabla NY_TAXI_TRIPS_UNIFIED actualizada exitosamente
# Guardados correctamente datos de taxis de year 2025 + month 12
