# %%
# !pip install python-dotenv
# !pip install snowflake-connector-python
# Out:
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: snowflake-connector-python in /opt/conda/lib/python3.11/site-packages (4.0.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (41.0.4)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (23.2.0)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.8.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.31.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (23.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2023.7.22)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (4.8.0)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.20.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.11.0)
# Requirement already satisfied: tomlkit in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (0.13.3)
# Requirement already satisfied: boto3>=1.24 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.40.55)
# Requirement already satisfied: botocore>=1.24 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.40.55)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore>=1.24->snowflake-connector-python) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore>=1.24->snowflake-connector-python) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=3.1.0->snowflake-connector-python) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.1.0->snowflake-connector-python) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.24->snowflake-connector-python) (1.16.0)

# %%
from dotenv import load_dotenv
import os
import pyspark
from pyspark.sql import SparkSession
import requests
import json
from pyspark.sql import functions as F
from pyspark.sql.types import StringType
import time

# %%
# Cargo mis variables de entorno
load_dotenv()

# Genero el dict de datos para conectarme con Snowflake a schema Raw
credencialesSnowflakeAnalytics = {
    "sfURL" : os.getenv("SNOWFLAKE_URL"),
    "sfUser" :  os.getenv("SNOWFLAKE_USER"),
    "sfPassword" : os.getenv("SNOWFLAKE_PASSWORD"),
    "sfDatabase" : os.getenv("SNOWFLAKE_DATABASE"),
    "sfSchema" : os.getenv("SNOWFLAKE_SCHEMA_ANALYTICS"),
    "sfWarehouse" : os.getenv("SNOWFLAKE_WAREHOUSE"),
    "sfRole" : os.getenv("SNOWFLAKE_ROLE"),
}

print(f"Estas son mis credenciales para Snowflake con schema Analytics: {credencialesSnowflakeAnalytics}")
# Out:
# Estas son mis credenciales para Snowflake con schema Analytics: {'sfURL': 'LSNDJXB-RHC82043.snowflakecomputing.com', 'sfUser': 'usuario_spark', 'sfPassword': 'EstudianteEstudiante64', 'sfDatabase': 'NY_TAXI', 'sfSchema': 'ANALYTICS', 'sfWarehouse': 'WAREHOUSE_TAXIS', 'sfRole': 'rol_pocos_privilegios'}

# %%
# Creo SparkSession para conexión con Snowflake
spark = (SparkSession.builder.appName("IngestaNewYorkTaxis").config("spark.jars.packages", "net.snowflake:snowflake-jdbc:3.13.30,net.snowflake:spark-snowflake_2.12:2.9.0-spark_3.1").getOrCreate())

print(spark)
print("Spark Version : " + spark.version)

# Ejecuto una query de prueba para validar comunicacion con Snowflake
query = "SELECT current_version()"

df = spark.read.format("snowflake").options(**credencialesSnowflakeAnalytics).option("query", query).load()

df.show()
# Out:
# <pyspark.sql.session.SparkSession object at 0x79e76f2db990>
# Spark Version : 3.5.0
# +-------------------+
# |"CURRENT_VERSION()"|
# +-------------------+
# |             9.32.1|
# +-------------------+

# %%
def generar_tabla_con_validaciones():

    print("Iniciando proceso de carga de datos de la OBT desde Schema Analytics para su validacion")

    try:
        df_obt = spark.read.format("snowflake") \
                .options(**credencialesSnowflakeAnalytics) \
                .option("dbtable", "NY_TAXI_OBT") \
                .load()

        df_obt_sin_nulos = df_obt.filter(F.col("DO_LOCATION_ID").isNotNull() & F.col("PASSENGER_COUNT").isNotNull() & F.col("PAYMENT_TYPE").isNotNull() & F.col("PU_LOCATION_ID").isNotNull() & F.col("RATE_CODE_ID").isNotNull() & F.col("DROPOFF_DATETIME").isNotNull() & F.col("PICKUP_DATETIME").isNotNull() & F.col("TRIP_DISTANCE").isNotNull() & F.col("VENDOR_ID").isNotNull())

        df_con_datos_coherentes = df_obt_sin_nulos.filter((F.col("PASSENGER_COUNT")>0) & (F.col("PASSENGER_COUNT")<10) & (F.col("EXTRA")>=0) & (F.col("FARE_AMOUNT")>=0) & (F.col("METROPOLITAN_TAX")>=0) & (F.col("TIP_AMOUNT")>=0) & (F.col("TOLLS_AMOUNT")>=0) & (F.col("TOTAL_AMOUNT")>=0) & (F.col("TRIP_DISTANCE")>0) & (F.col("TRIP_DURATION_MIN")>1) & (F.col("TRIP_DURATION_MIN")<180) & (F.col("AVG_SPEED_MPH")>0) & (F.col("AVG_SPEED_MPH")<100) & (F.col("TIP_PCT")>=0) & (F.col("PU_LOCATION_ID").between(1, 265)) & (F.col("DO_LOCATION_ID").between(1, 265)))
        
        df_con_fechas_coherentes= df_con_datos_coherentes.filter((F.col("MONTH")>0) & (F.col("MONTH")<13) & (F.col("YEAR")>=2015) & (F.col("YEAR")<=2025))

        print("Tabla OBT con validaciones generada correctamente")
        
        return df_con_fechas_coherentes
        
    except Exception as e:
        print(f"No se pudo generar la tabla OBT de Taxis con validaciones: {e}")
        raise e

# %%
def guardar_con_reintentos(df, tabla, reintentos=3):
    
    for intento in range(reintentos):
        try:
            print(f"Intento {intento + 1} de {reintentos} para guardar en {tabla}")
            df.write.format("snowflake") \
                .options(**credencialesSnowflakeAnalytics) \
                .option("dbtable", tabla) \
                .option("parallelism", 16) \
                .mode("append") \
                .save()
            
            print(f"Datos agregados exitosamente a TABLA OBT con Validaciones")
            return True
            
        except Exception as e:
            print(f"Error en intento {intento + 1}: {str(e)[:200]}...")
            if intento < reintentos - 1:
                wait_time = 30 
                print(f"Esperando {wait_time} segundos antes del reintento")
                time.sleep(wait_time)
            else:
                print(f"Todos los intentos fallaron para {tabla}")
                raise e

def guardar_por_lotes(df, tabla, batch_size=500000):
    
    total_count = df.count()
    num_partitions = max(1, total_count // batch_size)
    
    print(f"Dividiendo {total_count} filas en {num_partitions} particiones")
    
    df_reparticionado = df.repartition(num_partitions)
    
    return guardar_con_reintentos(df_reparticionado, tabla)

# %%
#Defino funciones tipicas de checkpoint para en caso de fallo no ingestar datos desde cero

def save_checkpoint(year, month, CHECKPOINT_FILE_COMBINADO):
    with open(CHECKPOINT_FILE_COMBINADO, "w") as f:
        json.dump({"year": year, "month": month}, f)

def load_checkpoint(CHECKPOINT_FILE_COMBINADO):
    if os.path.exists(CHECKPOINT_FILE_COMBINADO):
        with open(CHECKPOINT_FILE_COMBINADO, "r") as f:
            return json.load(f)
    return {"year": 0, "month": 0}

# %%
def cargar_tabla_obt_filtrada_snowflake():

    print("Iniciando proceso de generación de tabla OBT")
    
    try:
        tabla_destino="NY_TAXI_OBT_ULTIMATE"
        CHECKPOINT_FILE_OBT="checkpointCargaOBTUltimate.json"

        df_obt = generar_tabla_con_validaciones()
        print(df_obt.count())

        lista_years = sorted([int(item) for item in (os.getenv("YEARS").split(','))])
        lista_months = sorted([int(item) for item in (os.getenv("MONTHS").split(','))])
            
        checkpoint=load_checkpoint(CHECKPOINT_FILE_OBT)
        print(f"checkpoint: {checkpoint}")

        if ( checkpoint != {"year": 0, "month": 0} and (int(checkpoint["month"]) in lista_months) and (int(checkpoint["year"]) in lista_years)):    
            if ( int(checkpoint["month"]) == lista_months[-1] and int(checkpoint["year"]) != lista_years[-1] ):
                lista_years= lista_years[lista_years.index(checkpoint["year"])+1:]
            elif ( int(checkpoint["month"]) != lista_months[-1] and int(checkpoint["year"]) != lista_years[-1] ): 
                lista_years= lista_years[lista_years.index(checkpoint["year"]):]
                lista_months= lista_months[lista_months.index(checkpoint["month"])+1:]

        for year in lista_years:
            for month in lista_months:
                df_lote = df_obt.filter((F.col("YEAR") == int(year)) & (F.col("MONTH") == int(month)))
                print(f"Tabla OBT validada generada exitosamente para {month}-{year}.Se procedera a cargarlos en la base de Snowflake")
                guardar_por_lotes(df_lote, tabla_destino)
                print(f"Guardados correctamente datos OBT validados de taxis de year {year} + month {month}")
                save_checkpoint(year, month, CHECKPOINT_FILE_OBT)
            lista_months = sorted([int(item) for item in (os.getenv("MONTHS").split(','))])
        return True 
                
    except Exception as e2:
        print(f"Error generando o subiendo tabla OBT a Snowflake: {e2}")
        return False

# %%
cargar_tabla_obt_filtrada_snowflake()
# Out:
# Iniciando proceso de generación de tabla OBT
# Iniciando proceso de carga de datos de la OBT desde Schema Analytics para su validacion
# Tabla OBT con validaciones generada correctamente
# 813032013
# checkpoint: {'year': 0, 'month': 0}
# Tabla OBT validada generada exitosamente para 1-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14074381 filas en 28 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o161.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 19 in stage 9.0 failed 1 times, most recent failure: Lost task 19.0 in stage 9.0 (T...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 1
# Tabla OBT validada generada exitosamente para 2-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13844963 filas en 27 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 2
# Tabla OBT validada generada exitosamente para 3-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14872512 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 3
# Tabla OBT validada generada exitosamente para 4-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14545126 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 4
# Tabla OBT validada generada exitosamente para 5-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 14755286 filas en 29 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 5
# Tabla OBT validada generada exitosamente para 6-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13789171 filas en 27 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 6
# Tabla OBT validada generada exitosamente para 7-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12938157 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 7
# Tabla OBT validada generada exitosamente para 8-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12498742 filas en 24 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 8
# Tabla OBT validada generada exitosamente para 9-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12540385 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 9
# Tabla OBT validada generada exitosamente para 10-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13751058 filas en 27 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 10
# Tabla OBT validada generada exitosamente para 11-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12654180 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o366.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 23 in stage 72.0 failed 1 times, most recent failure: Lost task 23.0 in stage 72.0 ...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 2: An error occurred while calling o381.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 22 in stage 75.0 failed 1 times, most recent failure: Lost task 22.0 in stage 75.0 ...
# Esperando 30 segundos antes del reintento
# Intento 3 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 11
# Tabla OBT validada generada exitosamente para 12-2015.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12880419 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2015 + month 12
# Tabla OBT validada generada exitosamente para 1-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12183252 filas en 24 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 1
# Tabla OBT validada generada exitosamente para 2-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12718682 filas en 25 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 2
# Tabla OBT validada generada exitosamente para 3-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13600383 filas en 27 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 3
# Tabla OBT validada generada exitosamente para 4-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13288002 filas en 26 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 4
# Tabla OBT validada generada exitosamente para 5-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 13189218 filas en 26 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 5
# Tabla OBT validada generada exitosamente para 6-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 12365772 filas en 24 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 6
# Tabla OBT validada generada exitosamente para 7-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11461777 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 7
# Tabla OBT validada generada exitosamente para 8-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11033864 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 8
# Tabla OBT validada generada exitosamente para 9-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11123307 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 9
# Tabla OBT validada generada exitosamente para 10-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11945579 filas en 23 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 10
# Tabla OBT validada generada exitosamente para 11-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11095356 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 11
# Tabla OBT validada generada exitosamente para 12-2016.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11513365 filas en 23 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o643.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 15 in stage 156.0 failed 1 times, most recent failure: Lost task 15.0 in stage 156....
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2016 + month 12
# Tabla OBT validada generada exitosamente para 1-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10639553 filas en 21 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 1
# Tabla OBT validada generada exitosamente para 2-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10056610 filas en 20 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 2
# Tabla OBT validada generada exitosamente para 3-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11298582 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 3
# Tabla OBT validada generada exitosamente para 4-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10974589 filas en 21 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o734.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 8 in stage 183.0 failed 1 times, most recent failure: Lost task 8.0 in stage 183.0 ...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 4
# Tabla OBT validada generada exitosamente para 5-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 11010542 filas en 22 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 5
# Tabla OBT validada generada exitosamente para 6-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10488890 filas en 20 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o787.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 16 in stage 198.0 failed 1 times, most recent failure: Lost task 16.0 in stage 198....
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 2: An error occurred while calling o802.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 8 in stage 201.0 failed 1 times, most recent failure: Lost task 8.0 in stage 201.0 ...
# Esperando 30 segundos antes del reintento
# Intento 3 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 6
# Tabla OBT validada generada exitosamente para 7-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9367201 filas en 18 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 7
# Tabla OBT validada generada exitosamente para 8-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9159277 filas en 18 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 8
# Tabla OBT validada generada exitosamente para 9-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9678189 filas en 19 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 9
# Tabla OBT validada generada exitosamente para 10-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10514387 filas en 21 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o893.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 3 in stage 228.0 failed 1 times, most recent failure: Lost task 3.0 in stage 228.0 ...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 10
# Tabla OBT validada generada exitosamente para 11-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9968675 filas en 19 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 11
# Tabla OBT validada generada exitosamente para 12-2017.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10214394 filas en 20 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2017 + month 12
# Tabla OBT validada generada exitosamente para 1-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9367383 filas en 18 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 1
# Tabla OBT validada generada exitosamente para 2-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9085142 filas en 18 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 2
# Tabla OBT validada generada exitosamente para 3-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 10055352 filas en 20 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o1003.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 4 in stage 261.0 failed 1 times, most recent failure: Lost task 4.0 in stage 261.0...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 2: An error occurred while calling o1018.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 1 in stage 264.0 failed 1 times, most recent failure: Lost task 1.0 in stage 264.0...
# Esperando 30 segundos antes del reintento
# Intento 3 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 3
# Tabla OBT validada generada exitosamente para 4-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9897908 filas en 19 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 4
# Tabla OBT validada generada exitosamente para 5-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9812436 filas en 19 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o1071.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 14 in stage 279.0 failed 1 times, most recent failure: Lost task 14.0 in stage 279...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 2: An error occurred while calling o1086.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 16 in stage 282.0 failed 1 times, most recent failure: Lost task 16.0 in stage 282...
# Esperando 30 segundos antes del reintento
# Intento 3 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 5
# Tabla OBT validada generada exitosamente para 6-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9247013 filas en 18 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 6
# Tabla OBT validada generada exitosamente para 7-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8343181 filas en 16 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 7
# Tabla OBT validada generada exitosamente para 8-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8324259 filas en 16 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 8
# Tabla OBT validada generada exitosamente para 9-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8506391 filas en 17 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 9
# Tabla OBT validada generada exitosamente para 10-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 9282922 filas en 18 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 10
# Tabla OBT validada generada exitosamente para 11-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8557541 filas en 17 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 11
# Tabla OBT validada generada exitosamente para 12-2018.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8598685 filas en 17 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 1: An error occurred while calling o1234.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 7 in stage 327.0 failed 1 times, most recent failure: Lost task 7.0 in stage 327.0...
# Esperando 30 segundos antes del reintento
# Intento 2 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Error en intento 2: An error occurred while calling o1249.save.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 3 in stage 330.0 failed 1 times, most recent failure: Lost task 3.0 in stage 330.0...
# Esperando 30 segundos antes del reintento
# Intento 3 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2018 + month 12
# Tabla OBT validada generada exitosamente para 1-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8048789 filas en 16 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 1
# Tabla OBT validada generada exitosamente para 2-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7354843 filas en 14 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 2
# Tabla OBT validada generada exitosamente para 3-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 8161878 filas en 16 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 3
# Tabla OBT validada generada exitosamente para 4-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7688428 filas en 15 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 4
# Tabla OBT validada generada exitosamente para 5-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7795010 filas en 15 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 5
# Tabla OBT validada generada exitosamente para 6-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7148346 filas en 14 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 6
# Tabla OBT validada generada exitosamente para 7-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6455027 filas en 12 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 7
# Tabla OBT validada generada exitosamente para 8-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6187154 filas en 12 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 8
# Tabla OBT validada generada exitosamente para 9-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6659310 filas en 13 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 9
# Tabla OBT validada generada exitosamente para 10-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 7271518 filas en 14 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 10
# Tabla OBT validada generada exitosamente para 11-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6918508 filas en 13 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 11
# Tabla OBT validada generada exitosamente para 12-2019.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6930166 filas en 13 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2019 + month 12
# Tabla OBT validada generada exitosamente para 1-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6415731 filas en 12 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 1
# Tabla OBT validada generada exitosamente para 2-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 6314819 filas en 12 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 2
# Tabla OBT validada generada exitosamente para 3-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3013514 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 3
# Tabla OBT validada generada exitosamente para 4-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 225395 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 4
# Tabla OBT validada generada exitosamente para 5-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 295416 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 5
# Tabla OBT validada generada exitosamente para 6-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 498816 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 6
# Tabla OBT validada generada exitosamente para 7-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 724838 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 7
# Tabla OBT validada generada exitosamente para 8-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 920048 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 8
# Tabla OBT validada generada exitosamente para 9-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1232909 filas en 2 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 9
# Tabla OBT validada generada exitosamente para 10-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1552911 filas en 3 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 10
# Tabla OBT validada generada exitosamente para 11-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1393930 filas en 2 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 11
# Tabla OBT validada generada exitosamente para 12-2020.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1346946 filas en 2 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2020 + month 12
# Tabla OBT validada generada exitosamente para 1-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1250238 filas en 2 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 1
# Tabla OBT validada generada exitosamente para 2-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1250310 filas en 2 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 2
# Tabla OBT validada generada exitosamente para 3-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1757806 filas en 3 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 3
# Tabla OBT validada generada exitosamente para 4-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 1994523 filas en 3 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 4
# Tabla OBT validada generada exitosamente para 5-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2323969 filas en 4 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 5
# Tabla OBT validada generada exitosamente para 6-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2638924 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 6
# Tabla OBT validada generada exitosamente para 7-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2613822 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 7
# Tabla OBT validada generada exitosamente para 8-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2571109 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 8
# Tabla OBT validada generada exitosamente para 9-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2734726 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 9
# Tabla OBT validada generada exitosamente para 10-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3249240 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 10
# Tabla OBT validada generada exitosamente para 11-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3270562 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 11
# Tabla OBT validada generada exitosamente para 12-2021.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3044797 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2021 + month 12
# Tabla OBT validada generada exitosamente para 1-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2342821 filas en 4 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 1
# Tabla OBT validada generada exitosamente para 2-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2816857 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 2
# Tabla OBT validada generada exitosamente para 3-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3429622 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 3
# Tabla OBT validada generada exitosamente para 4-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3398396 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 4
# Tabla OBT validada generada exitosamente para 5-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3366613 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 5
# Tabla OBT validada generada exitosamente para 6-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3328337 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 6
# Tabla OBT validada generada exitosamente para 7-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2983475 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 7
# Tabla OBT validada generada exitosamente para 8-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2977025 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 8
# Tabla OBT validada generada exitosamente para 9-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2986011 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 9
# Tabla OBT validada generada exitosamente para 10-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3438479 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 10
# Tabla OBT validada generada exitosamente para 11-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3054024 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 11
# Tabla OBT validada generada exitosamente para 12-2022.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3184858 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2022 + month 12
# Tabla OBT validada generada exitosamente para 1-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2932374 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 1
# Tabla OBT validada generada exitosamente para 2-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2777839 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 2
# Tabla OBT validada generada exitosamente para 3-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3240194 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 3
# Tabla OBT validada generada exitosamente para 4-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3121151 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 4
# Tabla OBT validada generada exitosamente para 5-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3327768 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 5
# Tabla OBT validada generada exitosamente para 6-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3128511 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 6
# Tabla OBT validada generada exitosamente para 7-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2753715 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 7
# Tabla OBT validada generada exitosamente para 8-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2670311 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 8
# Tabla OBT validada generada exitosamente para 9-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2650411 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 9
# Tabla OBT validada generada exitosamente para 10-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3287502 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 10
# Tabla OBT validada generada exitosamente para 11-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3134540 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 11
# Tabla OBT validada generada exitosamente para 12-2023.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3118727 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2023 + month 12
# Tabla OBT validada generada exitosamente para 1-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2762403 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 1
# Tabla OBT validada generada exitosamente para 2-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2756244 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 2
# Tabla OBT validada generada exitosamente para 3-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3075285 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 3
# Tabla OBT validada generada exitosamente para 4-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3026189 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 4
# Tabla OBT validada generada exitosamente para 5-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3234857 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 5
# Tabla OBT validada generada exitosamente para 6-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3043412 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 6
# Tabla OBT validada generada exitosamente para 7-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2717525 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 7
# Tabla OBT validada generada exitosamente para 8-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2638099 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 8
# Tabla OBT validada generada exitosamente para 9-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3060376 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 9
# Tabla OBT validada generada exitosamente para 10-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3339894 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 10
# Tabla OBT validada generada exitosamente para 11-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3180647 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 11
# Tabla OBT validada generada exitosamente para 12-2024.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3234565 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2024 + month 12
# Tabla OBT validada generada exitosamente para 1-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2848027 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 1
# Tabla OBT validada generada exitosamente para 2-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2687999 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 2
# Tabla OBT validada generada exitosamente para 3-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3111480 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 3
# Tabla OBT validada generada exitosamente para 4-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3090885 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 4
# Tabla OBT validada generada exitosamente para 5-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 3226460 filas en 6 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 5
# Tabla OBT validada generada exitosamente para 6-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2940827 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 6
# Tabla OBT validada generada exitosamente para 7-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2702710 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 7
# Tabla OBT validada generada exitosamente para 8-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 2538235 filas en 5 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 8
# Tabla OBT validada generada exitosamente para 9-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 18 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 9
# Tabla OBT validada generada exitosamente para 10-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 10
# Tabla OBT validada generada exitosamente para 11-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 11
# Tabla OBT validada generada exitosamente para 12-2025.Se procedera a cargarlos en la base de Snowflake
# Dividiendo 0 filas en 1 particiones
# Intento 1 de 3 para guardar en NY_TAXI_OBT_ULTIMATE
# Datos agregados exitosamente a TABLA OBT con Validaciones
# Guardados correctamente datos OBT validados de taxis de year 2025 + month 12
# True
