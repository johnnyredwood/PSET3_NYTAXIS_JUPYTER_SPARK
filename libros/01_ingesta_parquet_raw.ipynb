# %%
# !pip install python-dotenv
# !pip install snowflake-connector-python
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
# Collecting snowflake-connector-python
#   Downloading snowflake_connector_python-3.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 558.0 kB/s eta 0:00:00 0:00:01m
# Collecting asn1crypto<2.0.0,>0.24.0 (from snowflake-connector-python)
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting boto3>=1.24 (from snowflake-connector-python)
#   Downloading boto3-1.40.48-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore>=1.24 (from snowflake-connector-python)
#   Downloading botocore-1.40.48-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (1.16.0)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (41.0.4)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (23.2.0)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.8.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.31.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (23.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2023.7.22)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (4.8.0)
# Collecting filelock<4,>=3.5 (from snowflake-connector-python)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from snowflake-connector-python) (3.11.0)
# Collecting tomlkit (from snowflake-connector-python)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.24->snowflake-connector-python)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3>=1.24->snowflake-connector-python)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore>=1.24->snowflake-connector-python) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore>=1.24->snowflake-connector-python) (2.0.7)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.24->snowflake-connector-python) (1.16.0)
# Downloading snowflake_connector_python-3.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading boto3-1.40.48-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading botocore-1.40.48-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 825.2 kB/s eta 0:00:000:00:01
# Installing collected packages: asn1crypto, tomlkit, jmespath, filelock, botocore, s3transfer, boto3, snowflake-connector-python
# Successfully installed asn1crypto-1.5.1 boto3-1.40.48 botocore-1.40.48 filelock-3.20.0 jmespath-1.0.1 s3transfer-0.14.0 snowflake-connector-python-3.18.0 tomlkit-0.13.3

# %%
from dotenv import load_dotenv
import os

# Cargo mis variables de entorno
load_dotenv()

# Genero el dict de datos para conectarme con Snowflake
credencialesSnowflakeRaw = {
    "sfURL" : os.getenv("SNOWFLAKE_URL"),
    "sfUser" :  os.getenv("SNOWFLAKE_USER"),
    "sfPassword" : os.getenv("SNOWFLAKE_PASSWORD"),
    "sfDatabase" : os.getenv("SNOWFLAKE_DATABASE"),
    "sfSchema" : os.getenv("SNOWFLAKE_SCHEMA_RAW"),
    "sfWarehouse" : os.getenv("SNOWFLAKE_WAREHOUSE"),
    "sfRole" : os.getenv("SNOWFLAKE_ROLE"),
}

print(f"Estas son mis credenciales para Snowflake: {credencialesSnowflakeRaw}")
# Out:
# Estas son mis credenciales para Snowflake: {'sfURL': 'LSNDJXB-RHC82043.snowflakecomputing.com', 'sfUser': 'usuario_spark', 'sfPassword': 'EstudianteEstudiante64', 'sfDatabase': 'NY_TAXI', 'sfSchema': 'RAW', 'sfWarehouse': 'WAREHOUSE_TAXIS', 'sfRole': 'rol_pocos_privilegios'}

# %%
import pyspark
from pyspark.sql import SparkSession

# Creo SparkSession para conexión con Snowflake
spark = (SparkSession.builder.appName("IngestaNewYorkTaxis").config("spark.jars.packages", "net.snowflake:snowflake-jdbc:3.13.30,net.snowflake:spark-snowflake_2.12:2.9.0-spark_3.1").getOrCreate())

print(spark)
print("Spark Version : " + spark.version)

# Ejecuto una query de prueba para validar comunicacion con Snowflake
query = "SELECT current_version()"

df = spark.read.format("snowflake").options(**credencialesSnowflakeRaw).option("query", query).load()

df.show()
# Out:
# <pyspark.sql.session.SparkSession object at 0x7fb181e8f410>
# Spark Version : 3.5.0
# +-------------------+
# |"CURRENT_VERSION()"|
# +-------------------+
# |             9.31.0|
# +-------------------+

# %%
from pyspark.sql import types as T

def crear_tabla_raw_taxis(service: str):
    # Defino el esquema del DataFrame para asegurarme que los datos van a aterrizar correctamente en mi tabla
    
    schema = T.StructType([
        T.StructField("VENDORID", T.IntegerType(), False),
        T.StructField("TPEP_PICKUP_DATETIME", T.TimestampType(), False),
        T.StructField("TPEP_DROPOFF_DATETIME", T.TimestampType(), False),
        T.StructField("PASSENGER_COUNT", T.IntegerType(), True),
        T.StructField("TRIP_DISTANCE", T.FloatType(), True),
        T.StructField("RATECODEID", T.IntegerType(), True),
        T.StructField("STORE_AND_FWD_FLAG", T.StringType(), True),
        T.StructField("PULOCATIONID", T.IntegerType(), False),
        T.StructField("DOLOCATIONID", T.IntegerType(), False),
        T.StructField("PAYMENT_TYPE", T.IntegerType(), True),
        T.StructField("FARE_AMOUNT", T.FloatType(), True),
        T.StructField("EXTRA", T.FloatType(), True),
        T.StructField("MTA_TAX", T.FloatType(), True),
        T.StructField("TIP_AMOUNT", T.FloatType(), True),
        T.StructField("TOLLS_AMOUNT", T.FloatType(), True),
        T.StructField("IMPROVEMENT_SURCHARGE", T.FloatType(), True),
        T.StructField("TOTAL_AMOUNT", T.FloatType(), True),
        T.StructField("CONGESTION_SURCHARGE", T.FloatType(), True),
        T.StructField("RUN_ID", T.StringType(), True),
        T.StructField("SERVICE_TYPE", T.StringType(), True),
        T.StructField("SOURCE_YEAR", T.IntegerType(), True),
        T.StructField("SOURCE_MONTH", T.IntegerType(), True),
        T.StructField("INGESTED_AT_UTC", T.TimestampType(), True),
        T.StructField("SOURCE_PATH", T.StringType(), True)
    ])

    # Creo un DataFrame vacío con el esquema previamente definido por mi
    df_empty = spark.createDataFrame([], schema)

    # Escribo el DataFrame vacío en Snowflake para crear la tabla
    try:
        df_empty.write.format("snowflake") \
            .options(**credencialesSnowflakeRaw) \
            .option("dbtable", f"NY_TAXI_RAW_{service.upper()}") \
            .mode("ignore") \
            .save()

        print(f"Tabla NY_TAXI_RAW_{service.upper()} creada correctamente en Snowflake")
    except Exception as e:
        print(f"Fallo la creacion de la tabla de taxis: {e}")

# %%
import datetime

#Hago la presente funcion para generar un identificador unico asociado a cada carga de datos para el RUN_ID 
def generar_run_id():
    return datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# %%
import os 
import requests 
from pyspark.sql.functions import lit, current_timestamp 
from pyspark.sql.types import TimestampType

def ingestar_parquet_a_raw(service: str, year: int, month: int):
    SOURCE_PATH = os.getenv("SOURCE_PATH")
    path_url = f"{SOURCE_PATH}/trip-data/{service}_tripdata_{year}-{month:02d}.parquet"
    local_path = f"/tmp/{service}_tripdata_{year}-{month:02d}.parquet"
    
    # Descargo el archivo Parquet en carpeta temporal para posteriormente leerlo
    try:
        r = requests.get(path_url, stream=True)
        if r.status_code == 200:
            with open(local_path, 'wb') as f:
                for chunk in r.iter_content(chunk_size=10000000):
                    f.write(chunk)
        else:
            print(f"Archivo no encontrado en {path_url} (status {r.status_code})")
            return None
    except Exception as e:
        print(f"Error descargando {path_url}: {e}")
        return None
    else:
        print(f"Archivo obtenido exitosamente de: {path_url}")
    
    # Leo el archivo parquet en un df de Spark
    try:
        df = spark.read.parquet(local_path)
    except Exception as e:
        print(f"No se pudo leer {local_path}: {e}")
        return None
    else:
        print(f"Archivo leido exitosamente por Spark: {local_path}")

    run_id = generar_run_id()

    # Elimino columna conflictiva que solo esta presente en unos pocos parquets
    if 'cbd_congestion_fee' in df.columns:
        df = df.drop('cbd_congestion_fee')

    # Homogenizo nombres de columnas y las paso a mayusculas para integridad de tabla
    df = df.withColumnRenamed("LPEP_PICKUP_DATETIME", "TPEP_PICKUP_DATETIME").withColumnRenamed("LPEP_DROPOFF_DATETIME", "TPEP_DROPOFF_DATETIME")
    df = df.toDF(*[c.upper() for c in df.columns])

    # Añado los metadatos indicados en instrucciones de PSET
    df_meta = df.withColumn("run_id", lit(run_id)) \
                .withColumn("service_type", lit(service)) \
                .withColumn("source_year", lit(year)) \
                .withColumn("source_month", lit(month)) \
                .withColumn("ingested_at_utc", current_timestamp()) \
                .withColumn("source_path", lit(path_url))

    
    # Convierto tipos de fecha a Timestamp porque me estaba marcando error al enviar datos al Snowflake sin esta transformacion
    for field in df_meta.schema.fields:
        if field.dataType.typeName() == "timestamp_ntz":
            df_meta = df_meta.withColumn(field.name, df_meta[field.name].cast(TimestampType()))

    conteoFilas = df_meta.count()
    print(f"Ingestando hacia Snowflake {service} {year}-{month}. Total de filas: {conteoFilas}")

    try:
        # Mi logica para idempotencia consiste en por cada run enviar los datos a una tabla temporal luego hacer merge upsert con tabla Raw principal desde tabla temporal y luego borro la tabla temporal
        ingestar_con_tabla_temporal(df_meta, service, run_id)
    except Exception as e2:
        print(f"Error con tabla temporal: {e2}")
        return None

    #Me aseguro de eliminar el archivo parquet temporal
    try:
        os.remove(local_path)
        print(f"Archivo parquet temporal removido: {local_path}")
    except OSError as e:
        print(f"No se pudo remover el archivo parquet temporal {local_path}: {e}")

    #Retorno datos para tabla de conteos de datos consumidos por run
    return {
        "year": year,
        "month": month,
        "count": conteoFilas,
        "run_id": run_id,
        "service_type": service
    }

# %%
def ingestar_con_tabla_temporal(df_meta, service: str, run_id: str):

    # Creo tabla temporal en Snowflake
    temp_table_name = f"TEMP_{service.upper()}_{run_id.replace('-', '_')}"
    
    print(f"Creando tabla temporal: {temp_table_name}")
    
    # Escribo datos a tabla temporal en snowflake
    df_meta.write \
        .format("snowflake") \
        .options(**credencialesSnowflakeRaw) \
        .option("dbtable", temp_table_name) \
        .mode("overwrite") \
        .save()
    
    # Ejecuto Merge para idempotencia
    try:
        procesarTablaTempToRawTaxis(temp_table_name, service)
    except Exception as e4:
        print(f"Error en Merge: {e4}")
        raise e4
    else:
        print(f"Merge ejecutado exitosamente desde tabla temporal")

# %%
import snowflake.connector

def procesarTablaTempToRawTaxis(temp_table_name: str, service: str):

    #Esta sera mi query merge la cual verifica similitud con datos de clave natural (vendorID + timestamps + PU/DO) en caso de similitud hace update y sino hace insert de datos. Asi aseguro idempotencia y evito duplicados
    merge_query = f"""
    MERGE INTO {credencialesSnowflakeRaw['sfDatabase']}.{credencialesSnowflakeRaw['sfSchema']}.NY_TAXI_RAW_{service.upper()} AS target
    USING {credencialesSnowflakeRaw['sfDatabase']}.{credencialesSnowflakeRaw['sfSchema']}.{temp_table_name} AS source
    ON target.VENDORID = source.VENDORID 
       AND target.TPEP_PICKUP_DATETIME = source.TPEP_PICKUP_DATETIME 
       AND target.TPEP_DROPOFF_DATETIME = source.TPEP_DROPOFF_DATETIME
       AND target.PULOCATIONID = source.PULOCATIONID
       AND target.DOLOCATIONID = source.DOLOCATIONID
    WHEN MATCHED THEN
        UPDATE SET
            target.PASSENGER_COUNT = source.PASSENGER_COUNT,
            target.TRIP_DISTANCE = source.TRIP_DISTANCE,
            target.RATECODEID = source.RATECODEID,
            target.STORE_AND_FWD_FLAG = source.STORE_AND_FWD_FLAG,
            target.PAYMENT_TYPE = source.PAYMENT_TYPE,
            target.FARE_AMOUNT = source.FARE_AMOUNT,
            target.EXTRA = source.EXTRA,
            target.MTA_TAX = source.MTA_TAX,
            target.TIP_AMOUNT = source.TIP_AMOUNT,
            target.TOLLS_AMOUNT = source.TOLLS_AMOUNT,
            target.IMPROVEMENT_SURCHARGE = source.IMPROVEMENT_SURCHARGE,
            target.TOTAL_AMOUNT = source.TOTAL_AMOUNT,
            target.CONGESTION_SURCHARGE = source.CONGESTION_SURCHARGE,
            target.RUN_ID = source.RUN_ID,
            target.SERVICE_TYPE = source.SERVICE_TYPE,
            target.SOURCE_YEAR = source.SOURCE_YEAR,
            target.SOURCE_MONTH = source.SOURCE_MONTH,
            target.INGESTED_AT_UTC = source.INGESTED_AT_UTC,
            target.SOURCE_PATH = source.SOURCE_PATH
    WHEN NOT MATCHED THEN
        INSERT (
            VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, 
            TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, 
            PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, 
            IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, 
            RUN_ID, SERVICE_TYPE, SOURCE_YEAR, SOURCE_MONTH, INGESTED_AT_UTC, SOURCE_PATH
        ) VALUES (
            source.VENDORID, source.TPEP_PICKUP_DATETIME, source.TPEP_DROPOFF_DATETIME, 
            source.PASSENGER_COUNT, source.TRIP_DISTANCE, source.RATECODEID, 
            source.STORE_AND_FWD_FLAG, source.PULOCATIONID, source.DOLOCATIONID, 
            source.PAYMENT_TYPE, source.FARE_AMOUNT, source.EXTRA, source.MTA_TAX, 
            source.TIP_AMOUNT, source.TOLLS_AMOUNT, source.IMPROVEMENT_SURCHARGE, 
            source.TOTAL_AMOUNT, source.CONGESTION_SURCHARGE, 
            source.RUN_ID, source.SERVICE_TYPE, source.SOURCE_YEAR, source.SOURCE_MONTH, 
            source.INGESTED_AT_UTC, source.SOURCE_PATH
        )
    """

    #query para que posterior al merge se haga drop de tabla temporal
    drop_query= f"""DROP TABLE IF EXISTS {credencialesSnowflakeRaw['sfDatabase']}.{credencialesSnowflakeRaw['sfSchema']}.{temp_table_name}"""  

    try:
        conn = snowflake.connector.connect(
        user=os.getenv("SNOWFLAKE_USER"),
        password=os.getenv("SNOWFLAKE_PASSWORD"),
        account=os.getenv("SNOWFLAKE_ACCOUNT"),
        warehouse=os.getenv("SNOWFLAKE_WAREHOUSE"),
        database=os.getenv("SNOWFLAKE_DATABASE"),
        schema=os.getenv("SNOWFLAKE_SCHEMA_RAW")
        )
    
        cur = conn.cursor()

        #Hago la conexion con snowflake y ejecuto la query de merge y luego la de drop
        cur.execute(merge_query)
        cur.execute(drop_query)
    
        conn.commit()
        cur.close()
        conn.close()
        
    except Exception as e3:
        print(f"Fallo la migración de datos de la tabla temporal a la tabla Raw de Taxis {service}: {e3}")
        raise e3
    else:
        print(f"Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis {service}")

# %%
import json
import os
import requests

#Defino funciones tipicas de checkpoint para en caso de fallo no ingestar datos desde cero
def save_checkpoint(year, month):
    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"year": year, "month": month}, f)

def load_checkpoint(CHECKPOINT_FILE):
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, "r") as f:
            return json.load(f)
    return {"year": 0, "month": 0}

#Genero arreglo que contendra datos de ingesta para tabla de conteos
resultadosGeneralesIngesta=[]

try:
    #Leo los datos de tipos de taxis, years y months desde variables de entorno
    tipos_taxis=os.getenv("SERVICES").split(',')
    for tipo_taxi in tipos_taxis:
        
        lista_years = sorted([int(item) for item in (os.getenv("YEARS").split(','))])
        lista_months = sorted([int(item) for item in (os.getenv("MONTHS").split(','))])
        #Cargo el checkpoint y en caso de que tenga registros recorto los arreglos de months y years para recorrer desde ultima ingesta exitosa
        CHECKPOINT_FILE = f"checkpointTaxis{tipo_taxi.capitalize()}.json"
        print(CHECKPOINT_FILE)
        checkpoint=load_checkpoint(CHECKPOINT_FILE)
        print(f"checkpoint: {checkpoint}")
        
        if ( checkpoint != {"year": 0, "month": 0} and (int(checkpoint["month"]) in lista_months) and (int(checkpoint["year"]) in lista_years)):    
            if ( int(checkpoint["month"]) == lista_months[-1] and int(checkpoint["year"]) != lista_years[-1] ):
                lista_years= lista_years[lista_years.index(checkpoint["year"])+1:]
            elif ( int(checkpoint["month"]) == lista_months[-1] and int(checkpoint["year"]) == lista_years[-1] ): 
                continue
            else:
                lista_years= lista_years[lista_years.index(checkpoint["year"]):]
                lista_months= lista_months[lista_months.index(checkpoint["month"])+1:]

        crear_tabla_raw_taxis(tipo_taxi)
        
        for year_taxi in lista_years:
            for month_taxi in lista_months:  
                #Llamo a la funcion de ingesta de datos iterativamente para cada mes, year y tipo de taxi
                print(f"Iniciando ingesta de datos de taxis {tipo_taxi}: {month_taxi}-{year_taxi}")
                resultadosParciales=ingestar_parquet_a_raw(tipo_taxi, year_taxi, month_taxi)
                #Guardo los resultados y genero el checkpint
                if (resultadosParciales != None):
                    resultadosGeneralesIngesta.append(resultadosParciales)
                    save_checkpoint(year_taxi,month_taxi)
                
except Exception as e5:
    #Como en todas las funciones vistas hago manejo de errores
    print(f"Fallo el proceso de ingesta masiva de datos de taxis NY: {e5}")
else:
    print("El proceso de ingesta masiva de taxis NY fue exitoso")
# Out:
# checkpointTaxisYellow.json
# checkpoint: {'year': 0, 'month': 0}
# Tabla NY_TAXI_RAW_YELLOW creada correctamente en Snowflake
# Iniciando ingesta de datos de taxis yellow: 1-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-01.parquet
# Ingestando hacia Snowflake yellow 2015-1. Total de filas: 12741035
# Creando tabla temporal: TEMP_YELLOW_20251009_173030
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-02.parquet
# Ingestando hacia Snowflake yellow 2015-2. Total de filas: 12442394
# Creando tabla temporal: TEMP_YELLOW_20251009_173710
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-03.parquet
# Ingestando hacia Snowflake yellow 2015-3. Total de filas: 13342951
# Creando tabla temporal: TEMP_YELLOW_20251009_174342
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-04.parquet
# Ingestando hacia Snowflake yellow 2015-4. Total de filas: 13063758
# Creando tabla temporal: TEMP_YELLOW_20251009_175009
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-05.parquet
# Ingestando hacia Snowflake yellow 2015-5. Total de filas: 13157677
# Creando tabla temporal: TEMP_YELLOW_20251009_175705
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-06.parquet
# Ingestando hacia Snowflake yellow 2015-6. Total de filas: 12324936
# Creando tabla temporal: TEMP_YELLOW_20251009_180330
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-07.parquet
# Ingestando hacia Snowflake yellow 2015-7. Total de filas: 11559666
# Creando tabla temporal: TEMP_YELLOW_20251009_180918
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-08.parquet
# Ingestando hacia Snowflake yellow 2015-8. Total de filas: 11123123
# Creando tabla temporal: TEMP_YELLOW_20251009_181449
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-09.parquet
# Ingestando hacia Snowflake yellow 2015-9. Total de filas: 11218122
# Creando tabla temporal: TEMP_YELLOW_20251009_182100
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-10.parquet
# Ingestando hacia Snowflake yellow 2015-10. Total de filas: 12307333
# Creando tabla temporal: TEMP_YELLOW_20251009_182630
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-11.parquet
# Ingestando hacia Snowflake yellow 2015-11. Total de filas: 11305240
# Creando tabla temporal: TEMP_YELLOW_20251009_183405
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2015
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2015-12.parquet
# Ingestando hacia Snowflake yellow 2015-12. Total de filas: 11452996
# Creando tabla temporal: TEMP_YELLOW_20251009_184004
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2015-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-01.parquet
# Ingestando hacia Snowflake yellow 2016-1. Total de filas: 10905067
# Creando tabla temporal: TEMP_YELLOW_20251009_184530
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-02.parquet
# Ingestando hacia Snowflake yellow 2016-2. Total de filas: 11375412
# Creando tabla temporal: TEMP_YELLOW_20251009_185104
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-03.parquet
# Ingestando hacia Snowflake yellow 2016-3. Total de filas: 12203824
# Creando tabla temporal: TEMP_YELLOW_20251009_185726
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-04.parquet
# Ingestando hacia Snowflake yellow 2016-4. Total de filas: 11927996
# Creando tabla temporal: TEMP_YELLOW_20251009_190345
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-05.parquet
# Ingestando hacia Snowflake yellow 2016-5. Total de filas: 11832049
# Creando tabla temporal: TEMP_YELLOW_20251009_190928
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-06.parquet
# Ingestando hacia Snowflake yellow 2016-6. Total de filas: 11131645
# Creando tabla temporal: TEMP_YELLOW_20251009_191511
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-07.parquet
# Ingestando hacia Snowflake yellow 2016-7. Total de filas: 10294080
# Creando tabla temporal: TEMP_YELLOW_20251009_192053
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-08.parquet
# Ingestando hacia Snowflake yellow 2016-8. Total de filas: 9942263
# Creando tabla temporal: TEMP_YELLOW_20251009_192746
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-09.parquet
# Ingestando hacia Snowflake yellow 2016-9. Total de filas: 10116018
# Creando tabla temporal: TEMP_YELLOW_20251009_193426
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-10.parquet
# Ingestando hacia Snowflake yellow 2016-10. Total de filas: 10854626
# Creando tabla temporal: TEMP_YELLOW_20251009_194125
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-11.parquet
# Ingestando hacia Snowflake yellow 2016-11. Total de filas: 10102128
# Creando tabla temporal: TEMP_YELLOW_20251009_195144
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2016
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2016-12.parquet
# Ingestando hacia Snowflake yellow 2016-12. Total de filas: 10446697
# Creando tabla temporal: TEMP_YELLOW_20251009_195818
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2016-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-01.parquet
# Ingestando hacia Snowflake yellow 2017-1. Total de filas: 9710820
# Creando tabla temporal: TEMP_YELLOW_20251009_200402
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-02.parquet
# Ingestando hacia Snowflake yellow 2017-2. Total de filas: 9169775
# Creando tabla temporal: TEMP_YELLOW_20251009_200848
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-03.parquet
# Ingestando hacia Snowflake yellow 2017-3. Total de filas: 10295441
# Creando tabla temporal: TEMP_YELLOW_20251009_201421
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-04.parquet
# Ingestando hacia Snowflake yellow 2017-4. Total de filas: 10047135
# Creando tabla temporal: TEMP_YELLOW_20251009_201949
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-05.parquet
# Ingestando hacia Snowflake yellow 2017-5. Total de filas: 10102127
# Creando tabla temporal: TEMP_YELLOW_20251009_202501
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-06.parquet
# Ingestando hacia Snowflake yellow 2017-6. Total de filas: 9656993
# Creando tabla temporal: TEMP_YELLOW_20251009_203011
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-07.parquet
# Ingestando hacia Snowflake yellow 2017-7. Total de filas: 8588486
# Creando tabla temporal: TEMP_YELLOW_20251009_203509
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-08.parquet
# Ingestando hacia Snowflake yellow 2017-8. Total de filas: 8422153
# Creando tabla temporal: TEMP_YELLOW_20251009_203937
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-09.parquet
# Ingestando hacia Snowflake yellow 2017-9. Total de filas: 8945421
# Creando tabla temporal: TEMP_YELLOW_20251009_204407
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-10.parquet
# Ingestando hacia Snowflake yellow 2017-10. Total de filas: 9768672
# Creando tabla temporal: TEMP_YELLOW_20251009_204857
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-11.parquet
# Ingestando hacia Snowflake yellow 2017-11. Total de filas: 9284803
# Creando tabla temporal: TEMP_YELLOW_20251009_205353
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2017
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2017-12.parquet
# Ingestando hacia Snowflake yellow 2017-12. Total de filas: 9508501
# Creando tabla temporal: TEMP_YELLOW_20251009_205839
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2017-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-01.parquet
# Ingestando hacia Snowflake yellow 2018-1. Total de filas: 8760687
# Creando tabla temporal: TEMP_YELLOW_20251009_210316
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-02.parquet
# Ingestando hacia Snowflake yellow 2018-2. Total de filas: 8492819
# Creando tabla temporal: TEMP_YELLOW_20251009_210743
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-03.parquet
# Ingestando hacia Snowflake yellow 2018-3. Total de filas: 9431289
# Creando tabla temporal: TEMP_YELLOW_20251009_211214
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-04.parquet
# Ingestando hacia Snowflake yellow 2018-4. Total de filas: 9306216
# Creando tabla temporal: TEMP_YELLOW_20251009_211649
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-05.parquet
# Ingestando hacia Snowflake yellow 2018-5. Total de filas: 9224788
# Creando tabla temporal: TEMP_YELLOW_20251009_212119
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-06.parquet
# Ingestando hacia Snowflake yellow 2018-6. Total de filas: 8714667
# Creando tabla temporal: TEMP_YELLOW_20251009_212531
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-07.parquet
# Ingestando hacia Snowflake yellow 2018-7. Total de filas: 7851143
# Creando tabla temporal: TEMP_YELLOW_20251009_212939
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-08.parquet
# Ingestando hacia Snowflake yellow 2018-8. Total de filas: 7855040
# Creando tabla temporal: TEMP_YELLOW_20251009_213326
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-09.parquet
# Ingestando hacia Snowflake yellow 2018-9. Total de filas: 8049094
# Creando tabla temporal: TEMP_YELLOW_20251009_213712
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-10.parquet
# Ingestando hacia Snowflake yellow 2018-10. Total de filas: 8834520
# Creando tabla temporal: TEMP_YELLOW_20251009_214207
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-11.parquet
# Ingestando hacia Snowflake yellow 2018-11. Total de filas: 8155449
# Creando tabla temporal: TEMP_YELLOW_20251009_214628
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2018
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2018-12.parquet
# Ingestando hacia Snowflake yellow 2018-12. Total de filas: 8195675
# Creando tabla temporal: TEMP_YELLOW_20251009_215027
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2018-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-01.parquet
# Ingestando hacia Snowflake yellow 2019-1. Total de filas: 7696617
# Creando tabla temporal: TEMP_YELLOW_20251009_215432
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-02.parquet
# Ingestando hacia Snowflake yellow 2019-2. Total de filas: 7049370
# Creando tabla temporal: TEMP_YELLOW_20251009_215825
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-03.parquet
# Ingestando hacia Snowflake yellow 2019-3. Total de filas: 7866620
# Creando tabla temporal: TEMP_YELLOW_20251009_220210
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-04.parquet
# Ingestando hacia Snowflake yellow 2019-4. Total de filas: 7475949
# Creando tabla temporal: TEMP_YELLOW_20251009_220635
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-05.parquet
# Ingestando hacia Snowflake yellow 2019-5. Total de filas: 7598445
# Creando tabla temporal: TEMP_YELLOW_20251009_221036
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-06.parquet
# Ingestando hacia Snowflake yellow 2019-6. Total de filas: 6971560
# Creando tabla temporal: TEMP_YELLOW_20251009_221428
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-07.parquet
# Ingestando hacia Snowflake yellow 2019-7. Total de filas: 6310419
# Creando tabla temporal: TEMP_YELLOW_20251009_221755
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-08.parquet
# Ingestando hacia Snowflake yellow 2019-8. Total de filas: 6073357
# Creando tabla temporal: TEMP_YELLOW_20251009_222122
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-09.parquet
# Ingestando hacia Snowflake yellow 2019-9. Total de filas: 6567788
# Creando tabla temporal: TEMP_YELLOW_20251009_222448
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-10.parquet
# Ingestando hacia Snowflake yellow 2019-10. Total de filas: 7213891
# Creando tabla temporal: TEMP_YELLOW_20251009_222827
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-11.parquet
# Ingestando hacia Snowflake yellow 2019-11. Total de filas: 6878111
# Creando tabla temporal: TEMP_YELLOW_20251009_223231
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2019
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2019-12.parquet
# Ingestando hacia Snowflake yellow 2019-12. Total de filas: 6896317
# Creando tabla temporal: TEMP_YELLOW_20251009_223616
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2019-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-01.parquet
# Ingestando hacia Snowflake yellow 2020-1. Total de filas: 6405008
# Creando tabla temporal: TEMP_YELLOW_20251009_223958
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-02.parquet
# Ingestando hacia Snowflake yellow 2020-2. Total de filas: 6299367
# Creando tabla temporal: TEMP_YELLOW_20251009_224325
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-03.parquet
# Ingestando hacia Snowflake yellow 2020-3. Total de filas: 3007687
# Creando tabla temporal: TEMP_YELLOW_20251009_224631
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-04.parquet
# Ingestando hacia Snowflake yellow 2020-4. Total de filas: 238073
# Creando tabla temporal: TEMP_YELLOW_20251009_224804
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-05.parquet
# Ingestando hacia Snowflake yellow 2020-5. Total de filas: 348415
# Creando tabla temporal: TEMP_YELLOW_20251009_224826
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-06.parquet
# Ingestando hacia Snowflake yellow 2020-6. Total de filas: 549797
# Creando tabla temporal: TEMP_YELLOW_20251009_224851
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-07.parquet
# Ingestando hacia Snowflake yellow 2020-7. Total de filas: 800412
# Creando tabla temporal: TEMP_YELLOW_20251009_224924
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-08.parquet
# Ingestando hacia Snowflake yellow 2020-8. Total de filas: 1007286
# Creando tabla temporal: TEMP_YELLOW_20251009_225004
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-09.parquet
# Ingestando hacia Snowflake yellow 2020-9. Total de filas: 1341017
# Creando tabla temporal: TEMP_YELLOW_20251009_225053
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-10.parquet
# Ingestando hacia Snowflake yellow 2020-10. Total de filas: 1681132
# Creando tabla temporal: TEMP_YELLOW_20251009_225152
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-11.parquet
# Ingestando hacia Snowflake yellow 2020-11. Total de filas: 1509000
# Creando tabla temporal: TEMP_YELLOW_20251009_225253
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2020
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2020-12.parquet
# Ingestando hacia Snowflake yellow 2020-12. Total de filas: 1461898
# Creando tabla temporal: TEMP_YELLOW_20251009_225350
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2020-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-01.parquet
# Ingestando hacia Snowflake yellow 2021-1. Total de filas: 1369769
# Creando tabla temporal: TEMP_YELLOW_20251009_225450
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-01.parquet
# Iniciando ingesta de datos de taxis yellow: 2-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-02.parquet
# Ingestando hacia Snowflake yellow 2021-2. Total de filas: 1371709
# Creando tabla temporal: TEMP_YELLOW_20251009_225545
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-02.parquet
# Iniciando ingesta de datos de taxis yellow: 3-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-03.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-03.parquet
# Ingestando hacia Snowflake yellow 2021-3. Total de filas: 1925152
# Creando tabla temporal: TEMP_YELLOW_20251009_225646
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-03.parquet
# Iniciando ingesta de datos de taxis yellow: 4-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-04.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-04.parquet
# Ingestando hacia Snowflake yellow 2021-4. Total de filas: 2171187
# Creando tabla temporal: TEMP_YELLOW_20251009_225758
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-04.parquet
# Iniciando ingesta de datos de taxis yellow: 5-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-05.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-05.parquet
# Ingestando hacia Snowflake yellow 2021-5. Total de filas: 2507109
# Creando tabla temporal: TEMP_YELLOW_20251009_225921
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-05.parquet
# Iniciando ingesta de datos de taxis yellow: 6-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-06.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-06.parquet
# Ingestando hacia Snowflake yellow 2021-6. Total de filas: 2834264
# Creando tabla temporal: TEMP_YELLOW_20251009_230050
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-06.parquet
# Iniciando ingesta de datos de taxis yellow: 7-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-07.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-07.parquet
# Ingestando hacia Snowflake yellow 2021-7. Total de filas: 2821746
# Creando tabla temporal: TEMP_YELLOW_20251009_230225
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-07.parquet
# Iniciando ingesta de datos de taxis yellow: 8-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-08.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-08.parquet
# Ingestando hacia Snowflake yellow 2021-8. Total de filas: 2788757
# Creando tabla temporal: TEMP_YELLOW_20251009_230359
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-08.parquet
# Iniciando ingesta de datos de taxis yellow: 9-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-09.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-09.parquet
# Ingestando hacia Snowflake yellow 2021-9. Total de filas: 2963793
# Creando tabla temporal: TEMP_YELLOW_20251009_230537
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-09.parquet
# Iniciando ingesta de datos de taxis yellow: 10-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-10.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-10.parquet
# Ingestando hacia Snowflake yellow 2021-10. Total de filas: 3463504
# Creando tabla temporal: TEMP_YELLOW_20251009_230718
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-10.parquet
# Iniciando ingesta de datos de taxis yellow: 11-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-11.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-11.parquet
# Ingestando hacia Snowflake yellow 2021-11. Total de filas: 3472949
# Creando tabla temporal: TEMP_YELLOW_20251009_230906
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-11.parquet
# Iniciando ingesta de datos de taxis yellow: 12-2021
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-12.parquet
# Archivo leido exitosamente por Spark: /tmp/yellow_tripdata_2021-12.parquet
# Ingestando hacia Snowflake yellow 2021-12. Total de filas: 3214369
# Creando tabla temporal: TEMP_YELLOW_20251009_231057
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis yellow
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/yellow_tripdata_2021-12.parquet
# Iniciando ingesta de datos de taxis yellow: 1-2022
# ...
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-05.parquet
# Iniciando ingesta de datos de taxis green: 6-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-06.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-06.parquet
# Ingestando hacia Snowflake green 2023-6. Total de filas: 65550
# Creando tabla temporal: TEMP_GREEN_20251010_013321
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-06.parquet
# Iniciando ingesta de datos de taxis green: 7-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-07.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-07.parquet
# Ingestando hacia Snowflake green 2023-7. Total de filas: 61343
# Creando tabla temporal: TEMP_GREEN_20251010_013334
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-07.parquet
# Iniciando ingesta de datos de taxis green: 8-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-08.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-08.parquet
# Ingestando hacia Snowflake green 2023-8. Total de filas: 60649
# Creando tabla temporal: TEMP_GREEN_20251010_013346
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-08.parquet
# Iniciando ingesta de datos de taxis green: 9-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-09.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-09.parquet
# Ingestando hacia Snowflake green 2023-9. Total de filas: 65471
# Creando tabla temporal: TEMP_GREEN_20251010_013402
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-09.parquet
# Iniciando ingesta de datos de taxis green: 10-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-10.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-10.parquet
# Ingestando hacia Snowflake green 2023-10. Total de filas: 66177
# Creando tabla temporal: TEMP_GREEN_20251010_013415
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-10.parquet
# Iniciando ingesta de datos de taxis green: 11-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-11.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-11.parquet
# Ingestando hacia Snowflake green 2023-11. Total de filas: 64025
# Creando tabla temporal: TEMP_GREEN_20251010_013429
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-11.parquet
# Iniciando ingesta de datos de taxis green: 12-2023
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-12.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2023-12.parquet
# Ingestando hacia Snowflake green 2023-12. Total de filas: 64215
# Creando tabla temporal: TEMP_GREEN_20251010_013442
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2023-12.parquet
# Iniciando ingesta de datos de taxis green: 1-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-01.parquet
# Ingestando hacia Snowflake green 2024-1. Total de filas: 56551
# Creando tabla temporal: TEMP_GREEN_20251010_013454
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-01.parquet
# Iniciando ingesta de datos de taxis green: 2-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-02.parquet
# Ingestando hacia Snowflake green 2024-2. Total de filas: 53577
# Creando tabla temporal: TEMP_GREEN_20251010_013506
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-02.parquet
# Iniciando ingesta de datos de taxis green: 3-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-03.parquet
# Ingestando hacia Snowflake green 2024-3. Total de filas: 57457
# Creando tabla temporal: TEMP_GREEN_20251010_013520
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-03.parquet
# Iniciando ingesta de datos de taxis green: 4-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-04.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-04.parquet
# Ingestando hacia Snowflake green 2024-4. Total de filas: 56471
# Creando tabla temporal: TEMP_GREEN_20251010_013532
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-04.parquet
# Iniciando ingesta de datos de taxis green: 5-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-05.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-05.parquet
# Ingestando hacia Snowflake green 2024-5. Total de filas: 61003
# Creando tabla temporal: TEMP_GREEN_20251010_013543
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-05.parquet
# Iniciando ingesta de datos de taxis green: 6-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-06.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-06.parquet
# Ingestando hacia Snowflake green 2024-6. Total de filas: 54748
# Creando tabla temporal: TEMP_GREEN_20251010_013556
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-06.parquet
# Iniciando ingesta de datos de taxis green: 7-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-07.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-07.parquet
# Ingestando hacia Snowflake green 2024-7. Total de filas: 51837
# Creando tabla temporal: TEMP_GREEN_20251010_013607
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-07.parquet
# Iniciando ingesta de datos de taxis green: 8-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-08.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-08.parquet
# Ingestando hacia Snowflake green 2024-8. Total de filas: 51771
# Creando tabla temporal: TEMP_GREEN_20251010_013619
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-08.parquet
# Iniciando ingesta de datos de taxis green: 9-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-09.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-09.parquet
# Ingestando hacia Snowflake green 2024-9. Total de filas: 54440
# Creando tabla temporal: TEMP_GREEN_20251010_013631
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-09.parquet
# Iniciando ingesta de datos de taxis green: 10-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-10.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-10.parquet
# Ingestando hacia Snowflake green 2024-10. Total de filas: 56147
# Creando tabla temporal: TEMP_GREEN_20251010_013648
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-10.parquet
# Iniciando ingesta de datos de taxis green: 11-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-11.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-11.parquet
# Ingestando hacia Snowflake green 2024-11. Total de filas: 52222
# Creando tabla temporal: TEMP_GREEN_20251010_013701
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-11.parquet
# Iniciando ingesta de datos de taxis green: 12-2024
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-12.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2024-12.parquet
# Ingestando hacia Snowflake green 2024-12. Total de filas: 53994
# Creando tabla temporal: TEMP_GREEN_20251010_013714
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2024-12.parquet
# Iniciando ingesta de datos de taxis green: 1-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-01.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-01.parquet
# Ingestando hacia Snowflake green 2025-1. Total de filas: 48326
# Creando tabla temporal: TEMP_GREEN_20251010_013725
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-01.parquet
# Iniciando ingesta de datos de taxis green: 2-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-02.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-02.parquet
# Ingestando hacia Snowflake green 2025-2. Total de filas: 46621
# Creando tabla temporal: TEMP_GREEN_20251010_013737
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-02.parquet
# Iniciando ingesta de datos de taxis green: 3-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-03.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-03.parquet
# Ingestando hacia Snowflake green 2025-3. Total de filas: 51539
# Creando tabla temporal: TEMP_GREEN_20251010_013751
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-03.parquet
# Iniciando ingesta de datos de taxis green: 4-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-04.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-04.parquet
# Ingestando hacia Snowflake green 2025-4. Total de filas: 52132
# Creando tabla temporal: TEMP_GREEN_20251010_013802
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-04.parquet
# Iniciando ingesta de datos de taxis green: 5-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-05.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-05.parquet
# Ingestando hacia Snowflake green 2025-5. Total de filas: 55399
# Creando tabla temporal: TEMP_GREEN_20251010_013814
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-05.parquet
# Iniciando ingesta de datos de taxis green: 6-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-06.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-06.parquet
# Ingestando hacia Snowflake green 2025-6. Total de filas: 49390
# Creando tabla temporal: TEMP_GREEN_20251010_013826
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-06.parquet
# Iniciando ingesta de datos de taxis green: 7-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-07.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-07.parquet
# Ingestando hacia Snowflake green 2025-7. Total de filas: 48205
# Creando tabla temporal: TEMP_GREEN_20251010_013838
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-07.parquet
# Iniciando ingesta de datos de taxis green: 8-2025
# Archivo obtenido exitosamente de: https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-08.parquet
# Archivo leido exitosamente por Spark: /tmp/green_tripdata_2025-08.parquet
# Ingestando hacia Snowflake green 2025-8. Total de filas: 46306
# Creando tabla temporal: TEMP_GREEN_20251010_013850
# Se migro exitosamente los datos de la tabla temporal a la principal Raw de Taxis green
# Merge ejecutado exitosamente desde tabla temporal
# Archivo parquet temporal removido: /tmp/green_tripdata_2025-08.parquet
# Iniciando ingesta de datos de taxis green: 9-2025
# Archivo no encontrado en https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-09.parquet (status 403)
# Iniciando ingesta de datos de taxis green: 10-2025
# Archivo no encontrado en https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-10.parquet (status 403)
# Iniciando ingesta de datos de taxis green: 11-2025
# Archivo no encontrado en https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet (status 403)
# Iniciando ingesta de datos de taxis green: 12-2025
# Archivo no encontrado en https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-12.parquet (status 403)
# El proceso de ingesta masiva de taxis NY fue exitoso

# %%
print(resultadosGeneralesIngesta)
# Out:
# [{'year': 2015, 'month': 1, 'count': 12741035, 'run_id': '20251009_173030', 'service_type': 'yellow'}, {'year': 2015, 'month': 2, 'count': 12442394, 'run_id': '20251009_173710', 'service_type': 'yellow'}, {'year': 2015, 'month': 3, 'count': 13342951, 'run_id': '20251009_174342', 'service_type': 'yellow'}, {'year': 2015, 'month': 4, 'count': 13063758, 'run_id': '20251009_175009', 'service_type': 'yellow'}, {'year': 2015, 'month': 5, 'count': 13157677, 'run_id': '20251009_175705', 'service_type': 'yellow'}, {'year': 2015, 'month': 6, 'count': 12324936, 'run_id': '20251009_180330', 'service_type': 'yellow'}, {'year': 2015, 'month': 7, 'count': 11559666, 'run_id': '20251009_180918', 'service_type': 'yellow'}, {'year': 2015, 'month': 8, 'count': 11123123, 'run_id': '20251009_181449', 'service_type': 'yellow'}, {'year': 2015, 'month': 9, 'count': 11218122, 'run_id': '20251009_182100', 'service_type': 'yellow'}, {'year': 2015, 'month': 10, 'count': 12307333, 'run_id': '20251009_182630', 'service_type': 'yellow'}, {'year': 2015, 'month': 11, 'count': 11305240, 'run_id': '20251009_183405', 'service_type': 'yellow'}, {'year': 2015, 'month': 12, 'count': 11452996, 'run_id': '20251009_184004', 'service_type': 'yellow'}, {'year': 2016, 'month': 1, 'count': 10905067, 'run_id': '20251009_184530', 'service_type': 'yellow'}, {'year': 2016, 'month': 2, 'count': 11375412, 'run_id': '20251009_185104', 'service_type': 'yellow'}, {'year': 2016, 'month': 3, 'count': 12203824, 'run_id': '20251009_185726', 'service_type': 'yellow'}, {'year': 2016, 'month': 4, 'count': 11927996, 'run_id': '20251009_190345', 'service_type': 'yellow'}, {'year': 2016, 'month': 5, 'count': 11832049, 'run_id': '20251009_190928', 'service_type': 'yellow'}, {'year': 2016, 'month': 6, 'count': 11131645, 'run_id': '20251009_191511', 'service_type': 'yellow'}, {'year': 2016, 'month': 7, 'count': 10294080, 'run_id': '20251009_192053', 'service_type': 'yellow'}, {'year': 2016, 'month': 8, 'count': 9942263, 'run_id': '20251009_192746', 'service_type': 'yellow'}, {'year': 2016, 'month': 9, 'count': 10116018, 'run_id': '20251009_193426', 'service_type': 'yellow'}, {'year': 2016, 'month': 10, 'count': 10854626, 'run_id': '20251009_194125', 'service_type': 'yellow'}, {'year': 2016, 'month': 11, 'count': 10102128, 'run_id': '20251009_195144', 'service_type': 'yellow'}, {'year': 2016, 'month': 12, 'count': 10446697, 'run_id': '20251009_195818', 'service_type': 'yellow'}, {'year': 2017, 'month': 1, 'count': 9710820, 'run_id': '20251009_200402', 'service_type': 'yellow'}, {'year': 2017, 'month': 2, 'count': 9169775, 'run_id': '20251009_200848', 'service_type': 'yellow'}, {'year': 2017, 'month': 3, 'count': 10295441, 'run_id': '20251009_201421', 'service_type': 'yellow'}, {'year': 2017, 'month': 4, 'count': 10047135, 'run_id': '20251009_201949', 'service_type': 'yellow'}, {'year': 2017, 'month': 5, 'count': 10102127, 'run_id': '20251009_202501', 'service_type': 'yellow'}, {'year': 2017, 'month': 6, 'count': 9656993, 'run_id': '20251009_203011', 'service_type': 'yellow'}, {'year': 2017, 'month': 7, 'count': 8588486, 'run_id': '20251009_203509', 'service_type': 'yellow'}, {'year': 2017, 'month': 8, 'count': 8422153, 'run_id': '20251009_203937', 'service_type': 'yellow'}, {'year': 2017, 'month': 9, 'count': 8945421, 'run_id': '20251009_204407', 'service_type': 'yellow'}, {'year': 2017, 'month': 10, 'count': 9768672, 'run_id': '20251009_204857', 'service_type': 'yellow'}, {'year': 2017, 'month': 11, 'count': 9284803, 'run_id': '20251009_205353', 'service_type': 'yellow'}, {'year': 2017, 'month': 12, 'count': 9508501, 'run_id': '20251009_205839', 'service_type': 'yellow'}, {'year': 2018, 'month': 1, 'count': 8760687, 'run_id': '20251009_210316', 'service_type': 'yellow'}, {'year': 2018, 'month': 2, 'count': 8492819, 'run_id': '20251009_210743', 'service_type': 'yellow'}, {'year': 2018, 'month': 3, 'count': 9431289, 'run_id': '20251009_211214', 'service_type': 'yellow'}, {'year': 2018, 'month': 4 ...
